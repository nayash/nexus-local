# %%
import os

os.getcwd()
# Out:
# '/home/asutosh/Documents/projects/ml_projects/nexus-local/src/notebooks'

# %%
import sqlite3

DB_PATH = "../../data/sqlite/nexus.db"
def get_all_tables(db_path=DB_PATH):
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        return [row[0] for row in cursor.fetchall()]

def get_table_data(table_name, db_path=DB_PATH):
    import pandas as pd
    with sqlite3.connect(db_path) as conn:
        return pd.read_sql_query(f"SELECT * FROM {table_name}", conn)

# %%
get_all_tables()
# Out:
# ['chats', 'messages', 'sqlite_sequence']

# %%
get_table_data('chats')
# Out:
#                                      id                         title  \
# 0  7c265395-742f-46c8-aecd-d0ffbb773e69              Flet CLI Command
# 1  405d1a5f-db14-40ed-986a-cc47adc89509  Run Flet Application Command
# 2  5e103699-4163-4c01-957d-134a001581e9    Puzzle Project Ideas Found
# 3  58c14b92-dd1a-4471-9f0a-acf35674623b      Puzzle App Project Ideas
# 4  d0f97a00-f33c-4c82-9573-dd551f0c75b9         Puzzle Game App Ideas
# 5  78b2ed72-dfa3-4ebb-83d3-8dfd693c2424         Puzzle Game App Ideas
# 6  11423bd9-f45b-4640-a98e-b15c06d753f6     Puzzle Game Project Ideas
#
#                    created_at
# 0  2026-02-01 21:58:00.003758
# 1  2026-02-01 22:05:18.726549
# 2  2026-02-06 21:46:14.123044
# 3  2026-02-06 22:42:50.785374
# 4  2026-02-06 22:56:46.113382
# 5  2026-02-06 23:02:01.347313
# 6  2026-02-07 13:55:58.320531

# %%
get_table_data('messages')
# Out:
#     id                               chat_id       role  \
# 0   56  7c265395-742f-46c8-aecd-d0ffbb773e69       user
# 1   57  7c265395-742f-46c8-aecd-d0ffbb773e69  assistant
# 2   58  405d1a5f-db14-40ed-986a-cc47adc89509       user
# 3   59  405d1a5f-db14-40ed-986a-cc47adc89509  assistant
# 4   60  5e103699-4163-4c01-957d-134a001581e9       user
# 5   61  5e103699-4163-4c01-957d-134a001581e9  assistant
# 6   62  58c14b92-dd1a-4471-9f0a-acf35674623b       user
# 7   63  d0f97a00-f33c-4c82-9573-dd551f0c75b9       user
# 8   64  d0f97a00-f33c-4c82-9573-dd551f0c75b9  assistant
# 9   65  78b2ed72-dfa3-4ebb-83d3-8dfd693c2424       user
# 10  66  78b2ed72-dfa3-4ebb-83d3-8dfd693c2424  assistant
# 11  67  11423bd9-f45b-4640-a98e-b15c06d753f6       user
# 12  68  11423bd9-f45b-4640-a98e-b15c06d753f6  assistant
#
#                                               content  \
# 0   Look into my scripts folder data and tell me, ...
# 1   Since the `local_search_tool` did not find any...
# 2   look into my scripts folder and tell me, which...
# 3   The command to run the Flet Application is:\n\...
# 4   can you find if I had any puzzle idea for my p...
# 5   It seems like you have a few ideas for puzzles...
# 6     Did I have any puzzle app ideas in my projects?
# 7   Did I have any ideas for puzzle game apps in m...
# 8   Based on the search results, it appears that y...
# 9   Did I have any puzzle game app ideas in my pro...
# 10  Based on the search results, it appears that y...
# 11    Did I have any puzzle game idea in my projects?
# 12  Based on the search results, it appears that y...
#
#                     created_at
# 0   2026-02-01 21:58:00.023134
# 1   2026-02-01 22:00:39.368589
# 2   2026-02-01 22:05:18.738229
# 3   2026-02-01 22:06:53.952126
# 4   2026-02-06 21:46:14.134843
# 5   2026-02-06 21:46:52.811059
# 6   2026-02-06 22:42:50.797681
# 7   2026-02-06 22:56:46.125213
# 8   2026-02-06 22:57:29.972953
# 9   2026-02-06 23:02:01.359223
# 10  2026-02-06 23:02:06.184591
# 11  2026-02-07 13:55:58.334508
# 12  2026-02-07 13:56:13.912497

# %%
import lancedb
import pandas as pd

LANCEDB_PATH = "../../data/lancedb"

def list_lancedb_tables(db_path: str):
    """List all tables in the specified LanceDB database."""
    db = lancedb.connect(db_path)
    print(f'db: {db}')
    return db.table_names()

def preview_lancedb_table(db_path: str, table_name: str):
    """Preview the specified table from LanceDB."""
    db = lancedb.connect(db_path)
    print(f'db: {db}')
    table = db.open_table(table_name)
    df = table.search().to_pandas()
    return df

# %%
tables = list_lancedb_tables(LANCEDB_PATH)
tables
# Out:
# db: LanceDBConnection(uri='/home/asutosh/Documents/projects/ml_projects/nexus-local/src/notebooks/../../data/lancedb')
# /tmp/ipykernel_6864/2108785660.py:10: DeprecationWarning: table_names() is deprecated, use list_tables() instead
#   return db.table_names()
# ['nexus_parent_child']

# %%
df = preview_lancedb_table(LANCEDB_PATH, tables[0])
print(f'df: {len(df)}')
df.head(25)
# Out:
# db: LanceDBConnection(uri='/home/asutosh/Documents/projects/ml_projects/nexus-local/src/notebooks/../../data/lancedb')
# df: 19
#                                                vector  \
# 0   [-0.01833202, 0.010185653, -0.18143885, -0.051...
# 1   [0.005449516, -0.0043293536, -0.17812338, -0.0...
# 2   [0.017679704, 0.07456504, -0.18708915, -0.0274...
# 3   [0.04005739, 0.033952005, -0.16843913, -0.0641...
# 4   [-5.812119e-05, 0.009987792, -0.17804788, -0.0...
# 5   [0.044177365, 0.038153738, -0.18291418, -0.038...
# 6   [0.044177365, 0.038153738, -0.18291418, -0.038...
# 7   [-0.056409307, 0.062862284, -0.16527662, -0.01...
# 8   [0.016148074, 0.008072146, -0.18886997, -0.020...
# 9   [-0.009986808, 0.034111794, -0.18342674, -0.03...
# 10  [0.035079587, 0.004001361, -0.13400169, -3.581...
# 11  [0.019825323, 0.039738826, -0.19245003, -0.034...
# 12  [0.012232549, 0.024409207, -0.18010777, -0.059...
# 13  [-0.0139571745, -0.02763496, -0.19634247, -0.0...
# 14  [-0.024486376, 0.044295516, -0.16771765, -0.02...
# 15  [-0.033714097, 0.05355053, -0.1568444, -0.0493...
# 16  [0.026786957, 0.019046735, -0.14050053, -0.032...
# 17  [-0.010067843, 0.04420362, -0.1945552, -0.0088...
# 18  [0.01939913, 0.044559464, -0.16141197, -0.0227...
#
#                                       id  \
# 0   2eb70c93-cf9c-477d-a52b-fbe40bc7e7dd
# 1   36762c37-c5ad-4ea7-b714-f4837fd1ac0b
# 2   cc10071f-285a-4548-be50-a1a29ef71f11
# 3   6727cdcc-1019-4a62-8549-f71ac334fda8
# 4   f5bcf35a-97b1-49fd-b1b5-06283cc371b8
# 5   658b74ee-0310-447d-b212-4e6484f358f8
# 6   6a1a14f4-659a-4fdf-8e4b-eebb0d252f3a
# 7   12f14ecc-fe9c-47d6-be33-ca08e3d1d35c
# 8   f12d6661-b861-43b4-a3c8-78291b22a759
# 9   6159fdea-c241-4fa0-80d4-d0c40b50047b
# 10  330d6d20-6192-403e-b42f-6a1b8da8daca
# 11  d25f4172-c27a-4a86-9a72-3fa4ed7a9fb0
# 12  eb0ebd6a-1e95-4531-8d38-e72248890926
# 13  fd4cad29-a817-48d3-b7a1-64d9b75d32b3
# 14  a0e8379f-ba9b-411f-a974-c4a56725ef9b
# 15  56a4310b-8c53-4833-8745-8aff465f14e3
# 16  f1d7f422-2507-430d-b0f6-0fbd8565266d
# 17  0025e4fc-e341-4220-bbaa-89faae2d37ce
# 18  057770f2-71ec-4706-9a78-96331874ae30
#
#                                                  text  \
# 0   # ChatGPT response\n\n[ChatGPT](https://chatgp...
# 1   - **Framework**: Use **Node.js** (with **Expre...
# 2   - **Database**: Use a database like **PostgreS...
# 3   - **Real-Time Data**: Use **WebSockets** ([Soc...
# 4   - **Push Notifications (Optional)**: If real-t...
# 5                      ### 2. **Data Flow and Logic**
# 6                      ### 2. **Data Flow and Logic**
# 7   - **Step 1: Group Management**: When users cre...
# 8   - **Step 2: Location Updates**: Every minute, ...
# 9   - The backend identifies the user’s group.\n  ...
# 10                 ### 3. **Android App Development**
# 11  - **Location Tracking**:\n    - Use **FusedLoc...
# 12  - Use **OkHttp** or [**Socket.IO](http://socke...
# 13  - **LiveData** and **ViewModel** (from Android...
# 14  ### 4. **Security and Access Control**\n\n- **...
# 15             ### Summary of Key Tools and Libraries
# 16  1. **Backend**: Node.js/Spring Boot, WebSocket...
# 17  - Data Storage: Room (local database), LiveDat...
# 18  This architecture ensures real-time location u...
#
#                                              metadata
# 0   {'doc_id': '6071cbcc-4561-4813-8ce3-aa9eaafeb4...
# 1   {'doc_id': '6071cbcc-4561-4813-8ce3-aa9eaafeb4...
# 2   {'doc_id': '6071cbcc-4561-4813-8ce3-aa9eaafeb4...
# 3   {'doc_id': '6071cbcc-4561-4813-8ce3-aa9eaafeb4...
# 4   {'doc_id': '6071cbcc-4561-4813-8ce3-aa9eaafeb4...
# 5   {'doc_id': '6071cbcc-4561-4813-8ce3-aa9eaafeb4...
# 6   {'doc_id': '7f9166d1-095a-4fb4-935c-a58d22497a...
# 7   {'doc_id': '7f9166d1-095a-4fb4-935c-a58d22497a...
# 8   {'doc_id': '7f9166d1-095a-4fb4-935c-a58d22497a...
# 9   {'doc_id': '7f9166d1-095a-4fb4-935c-a58d22497a...
# 10  {'doc_id': '7f9166d1-095a-4fb4-935c-a58d22497a...
# 11  {'doc_id': '7f9166d1-095a-4fb4-935c-a58d22497a...
# 12  {'doc_id': '7f9166d1-095a-4fb4-935c-a58d22497a...
# 13  {'doc_id': '7f9166d1-095a-4fb4-935c-a58d22497a...
# 14  {'doc_id': '7f9166d1-095a-4fb4-935c-a58d22497a...
# 15  {'doc_id': '4a0a6452-651d-4f7f-b939-b2d9e4807b...
# 16  {'doc_id': '4a0a6452-651d-4f7f-b939-b2d9e4807b...
# 17  {'doc_id': '4a0a6452-651d-4f7f-b939-b2d9e4807b...
# 18  {'doc_id': '4a0a6452-651d-4f7f-b939-b2d9e4807b...

# %%
for row in df.iterrows():
    print(f">> {row[1]['metadata']['source']} => {row[1]['text']}")
# Out:
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => # ChatGPT response
#
# [ChatGPT](https://chatgpt.com/share/672632dd-9658-8009-b144-27eafffe349b)
#
# To achieve this group-based location sharing with real-time data handling and controlled access, here’s a recommended approach with appropriate tools and libraries.
#
# ### 1. **Backend API with Real-Time Capabilities**
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - **Framework**: Use **Node.js** (with **Express.js** or **NestJS**) or **Spring Boot**. These are robust for building RESTful APIs and can integrate real-time data services.
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - **Database**: Use a database like **PostgreSQL** or **MongoDB** to store GPS coordinates with information about user groups. PostGIS (for PostgreSQL) provides spatial data support, which may be helpful for advanced geospatial queries.
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - **Real-Time Data**: Use **WebSockets** ([Socket.IO](http://socket.io/) for Node.js or Spring WebSocket for Java) to enable real-time communication between your backend and Android clients. WebSockets are ideal here because they maintain an open connection to deliver frequent updates (every minute) with minimal latency.
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - **Push Notifications (Optional)**: If real-time is less critical, you can use **Firebase Cloud Messaging (FCM)** for delivering location updates.
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => ### 2. **Data Flow and Logic**
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => ### 2. **Data Flow and Logic**
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - **Step 1: Group Management**: When users create or join a group, your backend should manage group membership, linking each user to their group (e.g., store group ID in a `users` table).
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - **Step 2: Location Updates**: Every minute, each user sends their GPS coordinates to the backend via a REST API or WebSocket message. The backend stores this location and forwards it to the other group members.
# - **Step 3: Distribute Data**: When a location update is received:
#     - The backend identifies the user’s group.
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - The backend identifies the user’s group.
#     - It broadcasts the location update to the rest of the users in the same group via WebSocket.
# - **Database Schema Example**:
#     - `users`: stores user data and group affiliation.
#     - `groups`: manages group metadata.
#     - `locations`: stores timestamped user location data (latitude, longitude, user ID).
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => ### 3. **Android App Development**
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - **Location Tracking**:
#     - Use **FusedLocationProviderClient** (from Google Play Services) for efficient location tracking.
#     - Set it to capture and send coordinates every minute.
# - **Networking**:
#     - Use **Retrofit** for REST API calls to send location data to the backend.
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - Use **OkHttp** or [**Socket.IO](http://socket.io/) client** for WebSocket connections to receive location updates in real time.
# - **Data Handling**:
#     - Use **Room** (local database) to store recent location data for displaying group member locations even if offline.
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - **LiveData** and **ViewModel** (from Android Jetpack) to manage and observe data, ensuring the UI remains updated with location changes.
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => ### 4. **Security and Access Control**
#
# - **User Authentication**: Use **Firebase Authentication** or **OAuth** (e.g., Auth0) to secure API calls.
# - **Authorization**: Ensure location data is shared only within a user’s group, potentially using tokens or group verification checks in the backend.
#
# ### Summary of Key Tools and Libraries
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => ### Summary of Key Tools and Libraries
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => 1. **Backend**: Node.js/Spring Boot, WebSockets ([Socket.IO/Spring](http://socket.io/Spring) WebSocket), PostgreSQL/MongoDB.
# 2. **Real-Time Communication**: WebSocket (primary) and FCM (optional, as a fallback).
# 3. **Android**:
#     - Location Tracking: FusedLocationProviderClient.
#     - Networking: Retrofit (for REST), OkHttp/Socket.IO client (for WebSocket).
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => - Data Storage: Room (local database), LiveData, and ViewModel (for UI updates).
# 4. **Security**: Firebase Authentication/OAuth for user authentication.
# >> /home/asutosh/Documents/ingested_docs/Private & Shared/Project Ideas/TripMate/ChatGPT response 132f28196ab680a180a2f532d8613628.md => This architecture ensures real-time location updates with scalable, group-based access controls while maintaining efficient resource use on both the backend and the Android clients.
#
# [Getting Started | Using WebSocket to build an interactive web application](https://spring.io/guides/gs/messaging-stomp-websocket)

# %%
# !ls '../../../../../'
# Out:
#  dashcam_complain		       'Procedural Generation in Games'
# 'google sys design 2 interview sheet'   projects
#  ingested_docs			        scripts
#  installations			        temp
#  models				        temp1
#  moltbook-agent			        temp_docs
#  nayash.github.io		        Twine
#  nayash.github.io-copy		        VIDEO_25072025194247_1753452767879.mp4
#  notes

# %%
for root, _, files in os.walk('../../../../../ingested_docs'):
    print(f'root={root}, _={_}, files={files}')
# Out:
# root=../../../../../ingested_docs, _=['Private & Shared'], files=['NestedLearning.pdf']
# root=../../../../../ingested_docs/Private & Shared, _=['Project Ideas'], files=['Project Ideas 70e616392f9446499e6f7da93016ddcf_all.csv', 'Project Ideas 70e616392f9446499e6f7da93016ddcf.csv']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas, _=['Recommendation system', '@Side-Hustle Ideas', 'Writing ideas', 'Nexus Local', 'TripMate'], files=['Notion templates to sell 283f28196ab68006a5abea65343349c1.md', 'Nexus Local 2edf28196ab68069b5b3c793ee2d68cb.md', 'Chrome extension to save snippets 282f28196ab680f19319c5036dc02319.md', 'Android expense tracker 258f28196ab680c4946efcbfb3be4ded.md', 'Recommendation system 106f28196ab680e38b96dcc192f58323.md', 'Writing ideas eb82935e544e4f55a7721b855efdd7af.md', 'Text Based Adventure - Abaddon Hotel cae65a64c0e04f8a9c64898ed4bda2a2.md', 'Android Chat Agent 258f28196ab680168ea1ffcbc1bdd26c.md', 'TripMate efd9cb3c97f04ae8ab8e67e78cd0a814.md', 'Android App for 2D, 3D geometry drawing & calculat 288f28196ab68058a0ebf86c20345afa.md', 'Android auto completion keyboard 288f28196ab680849b69c5f8c71c1576.md', 'P2P on Android ef0d33164c9f4a47a03cebbfff55196c.md', '@Side-Hustle Ideas 288f28196ab68037a8c9f93235e39762.md', '[Game] simple, adictive, level-based game built us 2c6f28196ab6809c8b06f6e847143ef6.md', '[cancel] Extension to do google search on text sel 289f28196ab6804c8f4ddb91d6ff7d3f.md', '[App] smart launcher with full home support using  2c6f28196ab680369f7dd21b15201849.md', 'E-Book publishing 223f28196ab68023b6d9d7bb458f8ec2.md', '[Game] multiplayer game like Undercover 2c6f28196ab680cc8b15e2699720448f.md', 'Sell on Gumroad 262f28196ab68070860cc077cbe468fa.md', '[Game] Jigsaw puzzle 2d7f28196ab680608e2bc6d5bd54da59.md', '[App] show word meaning as popup pn context menu c 292f28196ab680bea984e0982c4e9ad1.md', 'Try anti gravity ide 2edf28196ab680ae94eeebc82a44b44b.md', '[Game] Neon Rebus (Emoji translation) 2d5f28196ab680b485ffe1a24a9ad49a.md', '[Game] MemShuffle тАФ Card shuffle memory 2d5f28196ab6806bbaf4e01779f2e719.md']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas/Recommendation system, _=[], files=['Screenshot_from_2025-08-16_19-09-20.png']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas/@Side-Hustle Ideas, _=[], files=['NotebookLM Edu Videos 2edf28196ab680fcbd44ef788863769e.md']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas/Writing ideas, _=[], files=['Writing tips 236f28196ab680f1be3df0c5a13372d1.md', 'E-Book Ideas 27af28196ab68093bbcbe32bd8de95bf.md', 'DINOv3 250f28196ab68138a4bede4b4afa2466.md']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas/Nexus Local, _=[], files=['Product Requirement Document (PRD) Nexus-Local 2f1f28196ab680488781d6e64a33ddbe.md']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas/TripMate, _=[], files=['Commands a502fc8b63044edfae5143caee97322a.md', 'ChatGPT response 132f28196ab680a180a2f532d8613628.md']
