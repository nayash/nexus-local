# %%
import os

os.getcwd()
# Out:
# '/home/asutosh/Documents/projects/ml_projects/nexus-local/src/notebooks'

# %%
import sqlite3

DB_PATH = "../../data/sqlite/nexus.db"
def get_all_tables(db_path=DB_PATH):
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        return [row[0] for row in cursor.fetchall()]

def get_table_data(table_name, db_path=DB_PATH):
    import pandas as pd
    with sqlite3.connect(db_path) as conn:
        return pd.read_sql_query(f"SELECT * FROM {table_name}", conn)

# %%
get_all_tables()
# Out:
# ['chats', 'messages', 'sqlite_sequence']

# %%
get_table_data('chats')
# Out:
# Empty DataFrame
# Columns: [id, title, created_at]
# Index: []

# %%
get_table_data('messages')
# Out:
# Empty DataFrame
# Columns: [id, chat_id, role, content, created_at]
# Index: []

# %%
import lancedb
import pandas as pd

LANCEDB_PATH = "../../data/lancedb"

def list_lancedb_tables(db_path: str):
    """List all tables in the specified LanceDB database."""
    db = lancedb.connect(db_path)
    print(f'db: {db}')
    return db.table_names()

def preview_lancedb_table(db_path: str, table_name: str):
    """Preview the specified table from LanceDB."""
    db = lancedb.connect(db_path)
    print(f'db: {db}')
    table = db.open_table(table_name)
    df = table.search().to_pandas()
    return df

# %%
tables = list_lancedb_tables(LANCEDB_PATH)
tables
# Out:
# db: LanceDBConnection(uri='/home/asutosh/Documents/projects/ml_projects/nexus-local/src/notebooks/../../data/lancedb')
# /tmp/ipykernel_10544/2108785660.py:10: DeprecationWarning: table_names() is deprecated, use list_tables() instead
#   return db.table_names()
# ['documents', 'folder_home_asutosh_documents_ingested_docs']

# %%
df = preview_lancedb_table(LANCEDB_PATH, tables[1])
print(f'df: {df.size}')
df.head()
# Out:
# db: LanceDBConnection(uri='/home/asutosh/Documents/projects/ml_projects/nexus-local/src/notebooks/../../data/lancedb')
# df: 720
#                                               vector  \
# 0  [-0.008780854, 0.05926375, -0.14431177, -0.033...
# 1  [0.021357136, 0.07047814, -0.14556453, -0.0364...
# 2  [-0.0036714252, 0.03849432, -0.15729453, -0.06...
# 3  [0.04950246, 0.057295978, -0.1413394, -0.06618...
# 4  [0.009490604, 0.07480642, -0.1707146, -0.06438...
#
#                                                 text  \
# 0  Nested Learning: The Illusion of Deep Learning...
# 1  this paper, we present a new learning paradigm...
# 2  optimizers (e.g., Adam, SGD with Momentum, etc...
# 3  continual learning, and long-context reasoning...
# 4  Figure 1: The uniform and reusable structure a...
#
#                                               source  \
# 0  /home/asutosh/Documents/ingested_docs/NestedLe...
# 1  /home/asutosh/Documents/ingested_docs/NestedLe...
# 2  /home/asutosh/Documents/ingested_docs/NestedLe...
# 3  /home/asutosh/Documents/ingested_docs/NestedLe...
# 4  /home/asutosh/Documents/ingested_docs/NestedLe...
#
#                                           id
# 0  NestedLearning.pdf_0_-2872594983539481858
# 1   NestedLearning.pdf_1_3576633233139078817
# 2  NestedLearning.pdf_2_-4138935019671128734
# 3   NestedLearning.pdf_3_5029510789012030658
# 4   NestedLearning.pdf_4_4295071835871506384
