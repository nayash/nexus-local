# %%
import os

os.getcwd()
download_path = '../../../../../../Downloads'

# %%
import sqlite3

DB_PATH = "../../data/sqlite/nexus.db"
def get_all_tables(db_path=DB_PATH):
    with sqlite3.connect(db_path) as conn:
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        return [row[0] for row in cursor.fetchall()]

def get_table_data(table_name, db_path=DB_PATH):
    import pandas as pd
    with sqlite3.connect(db_path) as conn:
        return pd.read_sql_query(f"SELECT * FROM {table_name}", conn)

# %%
get_all_tables()
# Out:
# ['chats', 'messages', 'sqlite_sequence', 'watched_paths']

# %%
get_table_data('watched_paths')
# Out:
#                                      id  \
# 0  501c45f0-c653-4291-ba47-ca55f6d93788
#
#                                         path               table_name  status  \
# 0  /home/asutosh/Downloads/file_watcher_test  watch:file_watcher_test  active
#
#   last_scan             strategy                  created_at
# 0      None  organize_and_ingest  2026-03-01 23:55:36.024036

# %%
get_table_data('messages')
# Out:
#      id                               chat_id       role  \
# 0   294  813ee627-23de-494f-8898-534b33f146a3       user
# 1   295  813ee627-23de-494f-8898-534b33f146a3  assistant
# 2   296  813ee627-23de-494f-8898-534b33f146a3       user
# 3   297  813ee627-23de-494f-8898-534b33f146a3  assistant
# 4   298  813ee627-23de-494f-8898-534b33f146a3       user
# 5   299  813ee627-23de-494f-8898-534b33f146a3  assistant
# 6   300  813ee627-23de-494f-8898-534b33f146a3       user
# 7   301  813ee627-23de-494f-8898-534b33f146a3  assistant
# 8   302  813ee627-23de-494f-8898-534b33f146a3       user
# 9   303  813ee627-23de-494f-8898-534b33f146a3  assistant
# 10  304  813ee627-23de-494f-8898-534b33f146a3       user
# 11  305  813ee627-23de-494f-8898-534b33f146a3  assistant
# 12  306  813ee627-23de-494f-8898-534b33f146a3       user
# 13  307  813ee627-23de-494f-8898-534b33f146a3  assistant
# 14  308  813ee627-23de-494f-8898-534b33f146a3       user
# 15  309  813ee627-23de-494f-8898-534b33f146a3  assistant
# 16  310  813ee627-23de-494f-8898-534b33f146a3       user
# 17  311  813ee627-23de-494f-8898-534b33f146a3  assistant
# 18  312  813ee627-23de-494f-8898-534b33f146a3       user
# 19  313  cc9d0c66-4b12-480c-b079-e95d91fd2888       user
# 20  314  03973a28-cdd5-4ce9-966c-7585544b18b4       user
# 21  315  03973a28-cdd5-4ce9-966c-7585544b18b4  assistant
# 22  316  ea0c4ac5-fbc0-429d-b4d2-2ad29cfff9b8       user
# 23  317  ea0c4ac5-fbc0-429d-b4d2-2ad29cfff9b8  assistant
#
#                                               content  \
# 0                                                  hi
# 1                Hello! How can I assist you today? 😊
# 2                            what are you capable of?
# 3   I can help with web research, local file analy...
# 4                            what are you capable of?
# 5   I'm Nexus, your specialized research assistant...
# 6           what was the source of your above answer?
# 7   My previous answer was generated from my own k...
# 8              was there any T20 cricket match today?
# 9   Based on my search results, today is **Wednesd...
# 10                              Who is Asutosh Nayak?
# 11  Based on my search results, there are multiple...
# 12  Act as an expert crickt analyst and analyse va...
# 13  Based on my analysis of the T20 World Cup 2026...
# 14  can you tell what factors you considered and h...
# 15  # 📊 My Analytical Framework & Reasoning Proces...
# 16  Do similar analysis and predict seriously, Who...
# 17  Thank you for sharing these excerpts from the ...
# 18  no, answer who will win final cricket match ba...
# 19  write a code to implement binary search in Python
# 20  Give me an optimized code for implementing bin...
# 21  Here's an optimized binary search implementati...
# 22  Find the books I have in local storage by auth...
# 23  No books by Franz Kafka were found in your loc...
#
#                     created_at
# 0   2026-03-03 22:18:11.489017
# 1   2026-03-03 22:18:42.186023
# 2   2026-03-03 22:21:43.195764
# 3   2026-03-03 22:21:49.993982
# 4   2026-03-03 22:37:37.590857
# 5   2026-03-03 22:38:15.330844
# 6   2026-03-03 22:38:35.075104
# 7   2026-03-03 22:38:54.300174
# 8   2026-03-03 22:41:11.758814
# 9   2026-03-03 22:42:07.269880
# 10  2026-03-03 23:10:59.850471
# 11  2026-03-03 23:11:55.803538
# 12  2026-03-03 23:16:25.723161
# 13  2026-03-03 23:18:48.175959
# 14  2026-03-03 23:22:57.528602
# 15  2026-03-03 23:25:21.317566
# 16  2026-03-03 23:26:45.972587
# 17  2026-03-03 23:29:36.391805
# 18  2026-03-03 23:32:03.523897
# 19  2026-03-03 23:47:41.793005
# 20  2026-03-03 23:49:41.120553
# 21  2026-03-03 23:50:46.373928
# 22  2026-03-03 23:58:48.222115
# 23  2026-03-04 00:02:53.567876

# %%
import lancedb
import pandas as pd

LANCEDB_PATH = "../../data/lancedb"

def list_lancedb_tables(db_path: str):
    """List all tables in the specified LanceDB database."""
    db = lancedb.connect(db_path)
    print(f'db: {db}')
    return db.table_names()

def preview_lancedb_table(db_path: str, table_name: str):
    """Preview the specified table from LanceDB."""
    db = lancedb.connect(db_path)
    print(f'db: {db}')
    table = db.open_table(table_name)
    df = table.search().to_pandas()
    return df

# %%
tables = list_lancedb_tables(LANCEDB_PATH)
tables
# Out:
# db: LanceDBConnection(uri='/home/asutosh/Documents/projects/ml_projects/nexus-local/src/notebooks/../../data/lancedb')
# /tmp/ipykernel_9412/2108785660.py:10: DeprecationWarning: table_names() is deprecated, use list_tables() instead
#   return db.table_names()
# ['nexus_child_clip',
#  'nexus_child_text_nomic',
#  'nexus_documents',
#  'nexus_parents']

# %%
df = preview_lancedb_table(LANCEDB_PATH, tables[2])
print(f'df: {len(df)}')
df.head(7)
# Out:
# db: LanceDBConnection(uri='/home/asutosh/Documents/projects/ml_projects/nexus-local/src/notebooks/../../data/lancedb')
# df: 7
#                                               doc_id  \
# 0  0ea36d999272a1208f326d7aed9804527799836573c1f0...
# 1  d6a8fc80a683c0f493ebf801903738fc2fb81db66eddc0...
# 2  6c0d406facd5f12d3e52b9f40727c44917d0c30ce070fd...
# 3  f2ebc7fe2142daebf2115267090b06b9c4a1430ecd97cc...
# 4  7ea2f6a7d238013dc19702d27ac579c6f1c4e8b9eb804c...
# 5  dceffbd011efb826bdf0c4cc98d91bbba1bc80ad4c982e...
# 6  553a5233ba661938483da501c3bb93cda49f5194e8e215...
#
#                                          source_path  \
# 0  /home/asutosh/Downloads/file_watcher_test/Fina...
# 1  /home/asutosh/Downloads/file_watcher_test/Tech...
# 2  /home/asutosh/Downloads/file_watcher_test/Trav...
# 3  /home/asutosh/Downloads/file_watcher_test/Tech...
# 4  /home/asutosh/Downloads/file_watcher_test/Data...
# 5  /home/asutosh/Downloads/file_watcher_test/Iden...
# 6  /home/asutosh/Downloads/file_watcher_test/Tech...
#
#                                                 hash  \
# 0  0ea36d999272a1208f326d7aed9804527799836573c1f0...
# 1  d6a8fc80a683c0f493ebf801903738fc2fb81db66eddc0...
# 2  6c0d406facd5f12d3e52b9f40727c44917d0c30ce070fd...
# 3  f2ebc7fe2142daebf2115267090b06b9c4a1430ecd97cc...
# 4  7ea2f6a7d238013dc19702d27ac579c6f1c4e8b9eb804c...
# 5  dceffbd011efb826bdf0c4cc98d91bbba1bc80ad4c982e...
# 6  553a5233ba661938483da501c3bb93cda49f5194e8e215...
#
#                          indexed_at source_type  num_parents  num_children  \
# 0  2026-03-01T18:25:47.200491+00:00         pdf            9            36
# 1  2026-03-01T18:25:57.414455+00:00         txt            3            32
# 2  2026-03-01T18:26:00.578601+00:00       image            1             1
# 3  2026-03-01T18:26:28.419556+00:00         txt            4            38
# 4  2026-03-01T18:26:34.549376+00:00         txt           10           118
# 5  2026-03-01T18:26:38.904761+00:00       image            1             1
# 6  2026-03-01T18:26:48.820733+00:00         pdf           41           389
#
#   workspace_id                      file_name file_ext  \
# 0       global               190217091-BI.pdf     .pdf
# 1       global   file-watcher-instruction.txt     .txt
# 2       global            TheMuseJunction.png     .png
# 3       global  pip-packaging-instruction.txt     .txt
# 4       global     nexus-local-logs-debug.txt     .txt
# 5       global                  aadhaar_b.png     .png
# 6       global             NestedLearning.pdf     .pdf
#
#                        title author    owner document_kind  source_size_bytes  \
# 0               190217091-BI         asutosh      document             133364
# 1   file-watcher-instruction         asutosh      document               4720
# 2            TheMuseJunction         asutosh         image             627263
# 3  pip-packaging-instruction         asutosh      document               5699
# 4     nexus-local-logs-debug         asutosh           log              17694
# 5                  aadhaar_b         asutosh         image            3646186
# 6             NestedLearning         asutosh      document            2471247
#
#    source_mtime_epoch source_mtime_date  source_ctime_epoch source_ctime_date  \
# 0          1768731262        2026-01-18          1772389543        2026-03-01
# 1          1770529109        2026-02-08          1772389557        2026-03-01
# 2          1769403990        2026-01-26          1772389560        2026-03-01
# 3          1770490379        2026-02-08          1772389587        2026-03-01
# 4          1770399198        2026-02-06          1772389593        2026-03-01
# 5          1768046339        2026-01-10          1772389598        2026-03-01
# 6          1763145072        2025-11-15          1772389605        2026-03-01
#
#                                                extra
# 0  {"workspace_id": "global", "file_name": "19021...
# 1  {"workspace_id": "global", "file_name": "file-...
# 2  {"workspace_id": "global", "file_name": "TheMu...
# 3  {"workspace_id": "global", "file_name": "pip-p...
# 4  {"workspace_id": "global", "file_name": "nexus...
# 5  {"workspace_id": "global", "file_name": "aadha...
# 6  {"workspace_id": "global", "file_name": "Neste...

# %%
text = ''
count = 0
for row in df.iterrows():
    # if 'GAN' in row[1]['metadata']['source']:
    #     print(f">> {row[1]['metadata']}")
    #     text += row[1]['text']
    #     count += 1
    print(row[1]['metadata'])

print(count)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/projects/ml_projects/nexus-local/.flet-venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'metadata'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 8
#       2 count = 0
#       3 for row in df.iterrows():
#       4     # if 'GAN' in row[1]['metadata']['source']:
#       5     #     print(f">> {row[1]['metadata']}")
#       6     #     text += row[1]['text']
#       7     #     count += 1
# ----> 8     print(row[1]['metadata'])
#      10 print(count)
#
# File ~/Documents/projects/ml_projects/nexus-local/.flet-venv/lib/python3.12/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File ~/Documents/projects/ml_projects/nexus-local/.flet-venv/lib/python3.12/site-packages/pandas/core/series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File ~/Documents/projects/ml_projects/nexus-local/.flet-venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'metadata'

# %%
text
# Out:
# 'The GAN is dead; long live the GAN!\nA Modern Baseline GAN\nYiwen Huang\nBrown University\nAaron Gokaslan\nCornell University\nVolodymyr Kuleshov\nCornell University\nJames Tompkin\nBrown University\nAbstract\nThere is a widely-spread claim that GANs are difficult to train, and GAN archi-\ntectures in the literature are littered with empirical tricks. We provide evidenceagainst this claim and build a modern GAN baseline in a more principled manner.\nFirst, we derive a well-behaved regularized relativistic GAN loss that addresses\nissues of mode dropping and non-convergence that were previously tackled via a\nbag of ad-hoc tricks. We analyze our loss mathematically and prove that it admitslocal convergence guarantees, unlike most existing relativistic losses. Second, this\nloss allows us to discard all ad-hoc tricks and replace outdated backbones used\nin common GANs with modern architectures. Using StyleGAN2 as an example,\nwe present a roadmap of simplification and modernization that results in a new\nminimalist baseline—R3GAN (“Re-GAN”). Despite being simple, our approachsurpasses StyleGAN2 on FFHQ, ImageNet, CIFAR, and Stacked MNIST datasets,\nand compares favorably against state-of-the-art GANs and diffusion models.\nCode: https://www.github.com/brownvc/R3GAN\n1 Introduction\nGenerative adversarial networks (GANs) let us generate high-quality images in a single forward pass.However, the original objective in Goodfellowet al. [13], is notoriously difficult to optimize due to its\nminimax nature. This leads to a fear that training might diverge at any point due to instability, and a\nfear that generated images might lose diversity through mode collapse. While there has been progressin GAN objectives [14, 22, 81, 52, 64], practically, the effects of brittle losses are still regularly felt.\nThis notoriety has had a lasting negative impact on GAN research.\nA complementary issue—partly motivated by this instability—is that existing popular GAN backbonesThis notoriety has had a lasting negative impact on GAN research.\nA complementary issue—partly motivated by this instability—is that existing popular GAN backbones\nlike StyleGAN [29, 31, 30, 32] use many poorly-understood empirical tricks with little theory. For\ninstance, StyleGAN uses a gradient penalized non-saturating loss [52] to increase stability (affectingsample diversity), but then employs a minibatch standard deviation trick [ 28] to increase sample\ndiversity. Without tricks, the StyleGAN backbone still resembles DCGAN [ 60] from 2015, yet\nit is still the common backbone of SOTA GANs such as GigaGAN [ 26] and StyleGAN-T [ 70].\nAdvances in GANs have been conservative compared to other generative models such as diffusionmodels [ 20, 78, 33, 34], where modern computer vision techniques such as multi-headed self\nattention [87] and backbones such as preactivated ResNet [17], U-Net [63] and vision transformers\n(ViTs) [9] are the norm. Given outdated backbones, it is not surprising that there is a widely-spread\nbelief that GANs do not scale in terms of quantitative metrics like Frechet Inception Distance [19].We reconsider this situation: we show that by combining progress in objectives into a regularized\ntraining loss, GANs gain improved training stability, which allows us to upgrade GANs with modern\nbackbones. First, we propose a novel objective that augments the relativistic pairing GAN loss\n(RpGAN; [22]) with zero-centered gradient penalties [52, 64], improving stability [14, 64, 52]. Weshow mathematically that gradient-penalized RpGAN enjoys the same guarantee of local convergence\nas regularized classic GANs, and that removing our regularization scheme induces non-convergence.\n38th Conference on Neural Information Processing Systems (NeurIPS 2024).\narXiv:2501.05441v1  [cs.LG]  9 Jan 2025Once we have a well-behaved loss, none of the GAN tricks are necessary [ 28, 31], and we are\nfree to engineer a modern SOTA backbone architecture. We strip StyleGAN of all ...

# %%
for root, _, files in os.walk('../../../../../ingested_docs'):
    print(f'root={root}, _={_}, files={files}')
# Out:
# root=../../../../../ingested_docs, _=['Private & Shared'], files=['NestedLearning.pdf']
# root=../../../../../ingested_docs/Private & Shared, _=['Project Ideas'], files=['Project Ideas 70e616392f9446499e6f7da93016ddcf_all.csv', 'Project Ideas 70e616392f9446499e6f7da93016ddcf.csv']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas, _=['Recommendation system', '@Side-Hustle Ideas', 'Writing ideas', 'Nexus Local', 'TripMate'], files=['Notion templates to sell 283f28196ab68006a5abea65343349c1.md', 'Nexus Local 2edf28196ab68069b5b3c793ee2d68cb.md', 'Chrome extension to save snippets 282f28196ab680f19319c5036dc02319.md', 'Android expense tracker 258f28196ab680c4946efcbfb3be4ded.md', 'Recommendation system 106f28196ab680e38b96dcc192f58323.md', 'Writing ideas eb82935e544e4f55a7721b855efdd7af.md', 'Text Based Adventure - Abaddon Hotel cae65a64c0e04f8a9c64898ed4bda2a2.md', 'Android Chat Agent 258f28196ab680168ea1ffcbc1bdd26c.md', 'TripMate efd9cb3c97f04ae8ab8e67e78cd0a814.md', 'Android App for 2D, 3D geometry drawing & calculat 288f28196ab68058a0ebf86c20345afa.md', 'Android auto completion keyboard 288f28196ab680849b69c5f8c71c1576.md', 'P2P on Android ef0d33164c9f4a47a03cebbfff55196c.md', '@Side-Hustle Ideas 288f28196ab68037a8c9f93235e39762.md', '[Game] simple, adictive, level-based game built us 2c6f28196ab6809c8b06f6e847143ef6.md', '[cancel] Extension to do google search on text sel 289f28196ab6804c8f4ddb91d6ff7d3f.md', '[App] smart launcher with full home support using  2c6f28196ab680369f7dd21b15201849.md', 'E-Book publishing 223f28196ab68023b6d9d7bb458f8ec2.md', '[Game] multiplayer game like Undercover 2c6f28196ab680cc8b15e2699720448f.md', 'Sell on Gumroad 262f28196ab68070860cc077cbe468fa.md', '[Game] Jigsaw puzzle 2d7f28196ab680608e2bc6d5bd54da59.md', '[App] show word meaning as popup pn context menu c 292f28196ab680bea984e0982c4e9ad1.md', 'Try anti gravity ide 2edf28196ab680ae94eeebc82a44b44b.md', '[Game] Neon Rebus (Emoji translation) 2d5f28196ab680b485ffe1a24a9ad49a.md', '[Game] MemShuffle тАФ Card shuffle memory 2d5f28196ab6806bbaf4e01779f2e719.md']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas/Recommendation system, _=[], files=['Screenshot_from_2025-08-16_19-09-20.png']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas/@Side-Hustle Ideas, _=[], files=['NotebookLM Edu Videos 2edf28196ab680fcbd44ef788863769e.md']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas/Writing ideas, _=[], files=['Writing tips 236f28196ab680f1be3df0c5a13372d1.md', 'E-Book Ideas 27af28196ab68093bbcbe32bd8de95bf.md', 'DINOv3 250f28196ab68138a4bede4b4afa2466.md']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas/Nexus Local, _=[], files=['Product Requirement Document (PRD) Nexus-Local 2f1f28196ab680488781d6e64a33ddbe.md']
# root=../../../../../ingested_docs/Private & Shared/Project Ideas/TripMate, _=[], files=['Commands a502fc8b63044edfae5143caee97322a.md', 'ChatGPT response 132f28196ab680a180a2f532d8613628.md']

# %%
sales_file = f'{download_path}/sales_data_dummy.csv'

import pandas as pd

df =  pd.read_csv(sales_file)
df.head()
df.describe()
# Out:
#          Ad_Spend       Revenue  Units_Sold
# count    20.00000     20.000000   20.000000
# mean    987.52500   4502.562500   81.650000
# std     462.47832   2494.643939   38.361542
# min     400.00000   1800.000000   38.000000
# 25%     637.50000   2575.000000   50.000000
# 50%     825.00000   3500.000000   71.500000
# 75%    1275.00000   6200.375000  102.750000
# max    2100.00000  10500.000000  180.000000
